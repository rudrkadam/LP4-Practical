# %% [markdown]
# # Implement the Continuous Bag of Words (CBOW) Model
#
# Implement the Continuous Bag of Words (CBOW) Model for the given (textual document) using the below steps:
# 1. Data preparation
# 2. Generate training data
# 3. Train model
# 4. Output

# %% [markdown]
# ### 1. Data Preparation
# We start by defining the text data and performing initial preprocessing:
# - **Splitting sentences:** Split the paragraph into individual sentences based on periods to simplify tokenization.
# - **Cleaning sentences:** Remove non-alphabetic characters and convert text to lowercase for consistency.

# %%
import numpy as np
import re

# When data is given as a text file
file_path = 'CBOW.txt'

with open(file_path,'r') as file :
    file_contents = file.read()

data = file_contents

# data = """Deep learning (also known as deep structured learning) is part of a broader family of machine learning methods based on artificial neural networks with representation learning. Learning can be supervised, semi-supervised or unsupervised. Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, recurrent neural networks, convolutional neural networks and Transformers have been applied to fields including computer vision, speech recognition, natural language processing, machine translation, bioinformatics, drug design, medical image analysis, climate science, material inspection and board game programs, where they have produced results comparable to and in some cases surpassing human expert performance."""
# data = """Natural language processing (NLP) is a subfield of artificial intelligence (AI) focused on the interaction between computers and human language. The goal of NLP is to enable computers to understand, interpret, and generate human language in a way that is both meaningful and useful. NLP applications include speech recognition, machine translation, sentiment analysis, and chatbot development. Researchers in NLP use techniques such as tokenization, part-of-speech tagging, named entity recognition, and syntactic parsing to analyze and process text data."""


# Split and clean sentences
sentences = data.split('.')
clean_sent = [re.sub(r'(?:^| )\w (?:$| )', ' ', re.sub('[^A-Za-z0-9]+', ' ', sentence)).strip().lower() for sentence in sentences if sentence]

clean_sent
# Out:
# ['natural language processing nlp is a subfield of artificial intelligence ai focused on the interaction between computers and human language',
#  'the goal of nlp is to enable computers to understand interpret and generate human language in a way that is both meaningful and useful',
#  'nlp applications include speech recognition machine translation sentiment analysis and chatbot development',
#  'researchers in nlp use techniques such as tokenization part of speech tagging named entity recognition and syntactic parsing to analyze and process text data']

# %% [markdown]
# ### 2. Generate Training Data
# Using Keras’s `Tokenizer`, we convert words to integer indices:
# - **Tokenize sentences:** Convert cleaned sentences into sequences of integers.
# - **Create `index_to_word` and `word_to_index` mappings:** Establish mappings to translate between words and their integer representations.
# - **Define target and context words:** For each target word, the context consists of two words before and after it, making a "window" of context words.

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts(clean_sent)
sequences = tokenizer.texts_to_sequences(clean_sent)

# Mappings for word and index lookup
index_to_word = {i: word for i, word in enumerate(tokenizer.index_word.values(), start=1)}
word_to_index = tokenizer.word_index

# Prepare context-target pairs
vocab_size = len(tokenizer.word_index) + 1
emb_size = 10
context_size = 2

contexts = []
targets = []
for sequence in sequences:
    for i in range(context_size, len(sequence) - context_size):
        target = sequence[i]
        context = [sequence[i - 2], sequence[i - 1], sequence[i + 1], sequence[i + 2]]
        contexts.append(context)
        targets.append(target)

contexts[:5], targets[:5]
# Out:
# ([[14, 3, 2, 4], [3, 15, 4, 7], [15, 2, 7, 16], [2, 4, 16, 5], [4, 7, 5, 17]],
#  [15, 2, 4, 7, 16])

# %% [markdown]
# #### Display Some Training Samples
# Print examples of the context words and the corresponding target word to check data preparation.

# %%
for i in range(5):
    context_words = [index_to_word[idx] for idx in contexts[i]]
    target_word = index_to_word[targets[i]]
    print(f"Context: {context_words} -> Target: {target_word}")
# Out:
# Context: ['natural', 'language', 'nlp', 'is'] -> Target: processing
# Context: ['language', 'processing', 'is', 'a'] -> Target: nlp
# Context: ['processing', 'nlp', 'a', 'subfield'] -> Target: is
# Context: ['nlp', 'is', 'subfield', 'of'] -> Target: a
# Context: ['is', 'a', 'of', 'artificial'] -> Target: subfield

# %% [markdown]
# #### Prepare Data for Model Input
# Convert context and target data into numpy arrays for model training.

# %%
X = np.array(contexts)
Y = np.array(targets)

# %% [markdown]
# ### 3. Train the CBOW Model
# Define the CBOW model architecture using Keras:
# 1. **Embedding Layer:** Projects each word into an embedding space of specified dimensionality.
# 2. **Lambda Layer:** Calculates the mean of context embeddings.
# 3. **Dense Layers:** Two hidden layers for learning feature representations and an output layer with softmax for probability distribution across vocabulary words.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Lambda 

# Build the CBOW model
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=emb_size, input_length=2 * context_size),
    Lambda(lambda x: tf.reduce_mean(x, axis=1)),
    Dense(256, activation='relu'),
    Dense(512, activation='relu'),
    Dense(vocab_size, activation='softmax')
])

# Compile and train the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, epochs=80)
# Out:
# Epoch 1/80
# c:\Users\rudra\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# WARNING:tensorflow:From c:\Users\rudra\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\tensorflow\core.py:204: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.0000e+00 - loss: 4.0604
# Epoch 2/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1458 - loss: 4.0537
# Epoch 3/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1667 - loss: 4.0469
# Epoch 4/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1354 - loss: 4.0394
# Epoch 5/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1146 - loss: 4.0276
# Epoch 6/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1146 - loss: 4.0143
# Epoch 7/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0938 - loss: 4.0007
# Epoch 8/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0938 - loss: 3.9779
# Epoch 9/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1250 - loss: 3.9340
# Epoch 10/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0833 - loss: 3.9161
# Epoch 11/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0625 - loss: 3.8847
# Epoch 12/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0729 - loss: 3.8379
# Epoch 13/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0729 - loss: 3.8073
# Epoch 14/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0729 - loss: 3.7442
# Epoch 15/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0625 - loss: 3.7008
# Epoch 16/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0729 - loss: 3.6644
# Epoch 17/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0833 - loss: 3.6264
# Epoch 18/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0833 - loss: 3.5563
# Epoch 19/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1146 - loss: 3.5286
# Epoch 20/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1562 - loss: 3.4415
# Epoch 21/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1458 - loss: 3.3804
# Epoch 22/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1562 - loss: 3.3690
# Epoch 23/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1250 - loss: 3.3143
# Epoch 24/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.1875 - loss: 3.1879
# Epoch 25/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.1562 - loss: 3.1346
# Epoch 26/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1667 - loss: 3.1350
# Epoch 27/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1875 - loss: 3.0313
# Epoch 28/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1771 - loss: 2.9222
# Epoch 29/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.1875 - loss: 2.8378
# Epoch 30/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2083 - loss: 2.7980
# Epoch 31/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2292 - loss: 2.7603
# Epoch 32/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2396 - loss: 2.6547
# Epoch 33/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.2917 - loss: 2.5250
# Epoch 34/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2917 - loss: 2.4945
# Epoch 35/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3021 - loss: 2.3871
# Epoch 36/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3438 - loss: 2.2875
# Epoch 37/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3333 - loss: 2.2542
# Epoch 38/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3646 - loss: 2.1850
# Epoch 39/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3854 - loss: 2.1293
# Epoch 40/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4375 - loss: 2.0264
# Epoch 41/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5104 - loss: 1.9080
# Epoch 42/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4479 - loss: 1.8894
# Epoch 43/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5729 - loss: 1.7935
# Epoch 44/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5938 - loss: 1.7309
# Epoch 45/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6146 - loss: 1.6343
# Epoch 46/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6771 - loss: 1.6040
# Epoch 47/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6771 - loss: 1.5022
# Epoch 48/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6979 - loss: 1.4471
# Epoch 49/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7396 - loss: 1.3310
# Epoch 50/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 1.2350
# Epoch 51/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7188 - loss: 1.2522
# Epoch 52/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8021 - loss: 1.1163
# Epoch 53/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8542 - loss: 1.0761
# Epoch 54/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8333 - loss: 1.0331
# Epoch 55/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8750 - loss: 0.9669
# Epoch 56/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8542 - loss: 0.8998
# Epoch 57/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8542 - loss: 0.8291
# Epoch 58/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8854 - loss: 0.7926
# Epoch 59/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8958 - loss: 0.7522
# Epoch 60/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9583 - loss: 0.7024
# Epoch 61/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9792 - loss: 0.6556
# Epoch 62/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9688 - loss: 0.5737
# Epoch 63/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.5550
# Epoch 64/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9896 - loss: 0.5389
# Epoch 65/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.4723
# Epoch 66/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.4598
# Epoch 67/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.4175
# Epoch 68/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.3679
# Epoch 69/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 0.3583
# Epoch 70/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.3394
# Epoch 71/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.3059
# Epoch 72/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2861
# Epoch 73/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2503
# Epoch 74/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2550
# Epoch 75/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2354
# Epoch 76/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.2315
# Epoch 77/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.2030
# Epoch 78/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1902
# Epoch 79/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 1.0000 - loss: 0.1733
# Epoch 80/80
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 1.0000 - loss: 0.1656

# %% [markdown]
# #### Training Performance Visualization
# Plot training accuracy and loss to monitor the model's learning progress.

# %%
import matplotlib.pyplot as plt

# Plot the training loss and accuracy
plt.style.use("ggplot")  # Use ggplot style for better aesthetics
epochs_range = range(len(history.history['loss']))  # Get range based on actual epochs

# Create subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot Loss
ax1.plot(epochs_range, history.history['loss'], label="Training Loss")
ax1.set_title("Training Loss over Epochs")
ax1.set_xlabel("Epochs")
ax1.set_ylabel("Loss")
ax1.legend(loc="upper right")

# Plot Accuracy
ax2.plot(epochs_range, history.history['accuracy'], label="Training Accuracy", color="blue")
ax2.set_title("Training Accuracy over Epochs")
ax2.set_xlabel("Epochs")
ax2.set_ylabel("Accuracy")
ax2.legend(loc="lower right")

plt.suptitle("Training Performance (Loss and Accuracy)", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Output: Testing the Model on New Sentences
# Define sample sentences to test the model, converting them to integer indices before making predictions. Each sentence is split into words, indexed, and passed to the model to predict the target word based on context.

# %%
# test_sentences = [
#     "known as structured learning",
#     "transformers have applied to",
#     "where they produced results",
#     "cases surpassing expert performance"
# ]

test_sentences = [
    "language processing subfield artificial",  # should predict "intelligence"
    "goal NLP enable computers",  # should predict "to"
    "sentiment analysis chatbot development",  # should predict "and"
    "techniques named entity recognition"  # should predict "such"
]

for sent in test_sentences:
    words = sent.split()
    x_test = np.array([[word_to_index[word] for word in words if word in word_to_index]])
    prediction = model.predict(x_test)
    predicted_word = index_to_word[np.argmax(prediction)]
    print(f"Input: {words} -> Predicted word: {predicted_word}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input: ['language', 'processing', 'subfield', 'artificial'] -> Predicted word: of
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# Input: ['goal', 'NLP', 'enable', 'computers'] -> Predicted word: and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Input: ['sentiment', 'analysis', 'chatbot', 'development'] -> Predicted word: and
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# Input: ['techniques', 'named', 'entity', 'recognition'] -> Predicted word: named
